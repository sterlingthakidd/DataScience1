# %%
import pandas as pd

# %%
df = pd.read_csv("pirates.csv")

# %%
df.head(60)
# Out:
#     id     sex   age  height  weight headband college  tattoos  tchests  \
# 0    1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1    2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2    3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3    4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4    5  female  41.0  157.85    58.4      yes   JSSFP        9        6
# 5    6    male  26.0  190.20    85.4      yes    CCCC        7       19
# 6    7  female  31.0  158.05    59.6      yes   JSSFP        9        1
# 7    8  female  31.0  172.52    74.5      yes   JSSFP        5       13
# 8    9  female  28.0  164.57    68.7      yes   JSSFP       12       37
# 9   10    male  30.0  183.52    84.7      yes   JSSFP       12       69
# 10  11  female  25.0  162.49    63.5      yes    CCCC       10        1
# 11  12    male  20.0  163.65    70.0      yes    CCCC       14        5
# ...

# %%
df.info()
#df["parrots"].dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   object
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
# ...

# %%
#df = pd.read_csv("Head Injured Players.csv")
#df.head(5)

# %%
print("Single column value using dataframe[]")
print(df['headband'])
# Out:
# Single column value using dataframe[]
# 0      yes
# 1      yes
# 2      yes
# 3       no
# 4      yes
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    NaN
# Name: headband, Length: 1000, dtype: object

# %%
#for column in df.columns:
    #for row in range(len(df["id"])):
       # if pd.isna(df.iloc[row, column]):
           # print(row)
           # print(column)

# %%
print("Single column value using dataframe[]")
print(df['headband'])
# Out:
# Single column value using dataframe[]
# 0      yes
# 1      yes
# 2      yes
# 3       no
# 4      yes
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    NaN
# Name: headband, Length: 1000, dtype: object

# %%
#df.drop(33, inplace=True)

# %%
df['age'].mean()
# Out:
# 27.35735735735736

# %%
df.loc[33, 'age'] = df['age'].mean()

# %%
df.head(35)
# Out:
#     id     sex        age  height  weight headband college  tattoos  tchests  \
# 0    1    male  28.000000  173.11    70.5      yes   JSSFP        9        0
# 1    2    male  31.000000  209.25   105.6      yes   JSSFP        9       11
# 2    3    male  26.000000  169.95    77.1      yes    CCCC       10       10
# 3    4  female  31.000000  144.29    58.5       no   JSSFP        2        0
# 4    5  female  41.000000  157.85    58.4      yes   JSSFP        9        6
# 5    6    male  26.000000  190.20    85.4      yes    CCCC        7       19
# 6    7  female  31.000000  158.05    59.6      yes   JSSFP        9        1
# 7    8  female  31.000000  172.52    74.5      yes   JSSFP        5       13
# 8    9  female  28.000000  164.57    68.7      yes   JSSFP       12       37
# 9   10    male  30.000000  183.52    84.7      yes   JSSFP       12       69
# 10  11  female  25.000000  162.49    63.5      yes    CCCC       10        1
# ...

# %%
#rows_with_null = df.loc[df.isnull().any(axis=1)]
#columns_with_null = df.columns[df.isnull().any()]
#print("Rows with null values:")
#print(rows_with_null)

#print("\nColumns with null values:")
#print(columns_with_null)
# Out:
# Rows with null values:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
#
# Columns with null values:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df["age"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21192\1063941609.py in <module>
# ----> 1 df["age"].mean()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
number_genders = df['sex'].unique()
num_unique_genders = len(number_genders)
print("Number of genders:", num_unique_genders)
print('gender names:', number_genders)
# Out:
# Number of genders: 3
# gender names: ['male' 'female' 'other']

# %%
aver_age = df["age"].mean()
female_pirates = df[df['sex'] == 'female']
average_age_female = female_pirates['age'].mean()
print("average age", aver_age)
print("average age of female pirates", average_age_female)
# Out:
# average age 27.35735735735736
# average age of female pirates 29.922246220302377

# %%
# Out:
# Percentage of pirates weighing less than 100 pounds in kg: 100.0

# %%
lightweight_pirates = df[df['weight'] < 100]

# Calculate the percentage of lightweight pirates
total_pirates = len(df)
lightweight_pirates_count = len(lightweight_pirates)
percentage_lightweight = (lightweight_pirates_count / total_pirates) * 100

print("Percentage of pirates weighing less than 100 pounds:", percentage_lightweight, "%")
# Out:
# Percentage of pirates weighing less than 100 pounds: 2.2 %

# %%
df['weight_lb'] = df['weight']*2.2
percent = (df['weight_lb'] < 100).mean() * 100
print(percent)
# Out:
# 100.0

# %%
df['height_we'] = df['height']

# %%
shortest_height = df['height'].min()

print("Shortest height:", shortest_height)
# Out:
# Shortest height: 129.83

# %%
idx = df['height'].idxmin()
print(idx)
# Out:
# 38

# %%
df['fav.pixar'].mode()
# Out:
# 0    Inside Out
# Name: fav.pixar, dtype: object

# %%
average_num2 = df['eyepatch'].mean()
average_num3 = df['eyepatch'].median()
print("aver:", average_num2)
print("median:", average_num3)
# Out:
# aver: 0.658
# median: 1.0

# %%
#average_num4 = df['parrots'].mean()

# %%
df.loc[36, 'parrots'] = 1
idx = 0
for i in df['parrots']:
    df.loc[idx, 'parrots'] = int(i)
    idx = idx + 1

# %%
df['parrots'].mean()
# Out:
# 2.7109826589595376

# %%
df['parrots'].median()
# Out:
# 2.0

# %%
#challenge 7
existing_df = pd.read_csv('pirates.csv')
new_df = pd.read_csv('PirateNewRow.csv')
combined_df = pd.concat([existing_df, new_df], ignore_index=True)
# If you want to keep the original index, omit the `ignore_index=True` parameter.
# Write the concatenated DataFrame to a new CSV file
#combined_df.to_csv('combined_data.csv', index=False)

# %%
#df.head(1001)

# %%
newRow = pd.read_csv('PirateNewRow.csv')
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.drop["index"]

# %%
#challenge 8
newCol = pd.read_csv('PirateNewColumn.csv')

# %%
merged_df = pd.merge(combined_df, newCol, on='id', how='inner')

# %%
df.head()
# Out:
#    id     sex   age  height  weight headband college  tattoos  tchests  \
# 0   1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1   2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2   3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3   4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4   5  female  41.0  157.85    58.4      yes   JSSFP        9        6
#
#   parrots favorite.pirate sword.type  eyepatch  sword.time  beard.length  \
# 0       0    Jack Sparrow    cutlass         1        0.58            16
# 1       0    Jack Sparrow    cutlass         0        1.11            21
# 2       1    Jack Sparrow    cutlass         1        1.44            19
# 3       2    Jack Sparrow   scimitar         1       36.11             2
# 4       4            Hook    cutlass         1        0.11             0
#
#         fav.pixar  grogg
# 0  Monsters, Inc.     11
# 1          WALL-E      9
# ...
